# %%
import numpy as np
import pandas as pd

# %%
def load_results(file_name):
    r = np.genfromtxt(file_name, str)
    
    print("All")
    df = pd.DataFrame(r)
#     df.columns = ["Name", "Size", "Augmentation", "Accuracy"]
    print(df)
    
    print("\n*************************************************")
    print("Faces no augmentation")
    df2 = df.loc[df[0] == "faces"]
    df3 = df2.loc[df2[2] == "False"]
    print(df3)
    
    print("\n*************************************************")
    print("Faces augmentation")
    df2 = df.loc[df[0] == "faces"]
    df3 = df2.loc[df2[2] == "True"]
    print(df3)
    
    print("\n*************************************************")
    print("Clothes no augmentation")
    df2 = df.loc[df[0] == "clothes"]
    df3 = df2.loc[df2[2] == "False"]
    print(df3)
    
    print("\n*************************************************")
    print("Clothes augmentation")
    df2 = df.loc[df[0] == "clothes"]
    df3 = df2.loc[df2[2] == "True"]
    print(df3)
    


load_results("exp_sebastian.txt")

print("\n\n********************************")
print("********************************")

load_results("exp_jonathon.txt")
# Out:
# All
#           0      1      2               3
# 0     faces  100.0  False  0.336031764746
# 1   clothes  100.0  False  0.506142854691
# 2     faces  100.0   True   0.48507937789
# 3   clothes  100.0   True   0.75985711813
# 4     faces   75.0  False  0.341746032238
# 5   clothes   75.0  False  0.529857158661
# 6     faces   75.0   True  0.485555559397
# 7   clothes   75.0   True  0.780142843723
# 8     faces   50.0  False  0.349206358194
# 9   clothes   50.0  False  0.512857139111
# 10    faces   50.0   True  0.480793654919
# 11  clothes   50.0   True  0.764857113361
# 12    faces   25.0  False  0.337936520576
# 13  clothes   25.0  False  0.520285725594
# 14    faces   25.0   True  0.474285721779
# 15  clothes   25.0   True  0.738571405411
# 16    faces   10.0  False  0.338571429253
# 17  clothes   10.0  False   0.54757142067
# 18    faces   10.0   True  0.499682545662
# 19  clothes   10.0   True   0.77685713768
# 20    faces    1.0  False  0.319841265678
# 21  clothes    1.0  False  0.500999987125
# 22    faces    1.0   True  0.442222207785
# 23  clothes    1.0   True  0.763999998569
#
# *************************************************
# Faces no augmentation
#         0      1      2               3
# 0   faces  100.0  False  0.336031764746
# 4   faces   75.0  False  0.341746032238
# 8   faces   50.0  False  0.349206358194
# 12  faces   25.0  False  0.337936520576
# 16  faces   10.0  False  0.338571429253
# 20  faces    1.0  False  0.319841265678
#
# *************************************************
# Faces augmentation
#         0      1     2               3
# 2   faces  100.0  True   0.48507937789
# 6   faces   75.0  True  0.485555559397
# 10  faces   50.0  True  0.480793654919
# 14  faces   25.0  True  0.474285721779
# 18  faces   10.0  True  0.499682545662
# 22  faces    1.0  True  0.442222207785
#
# *************************************************
# Clothes no augmentation
#           0      1      2               3
# 1   clothes  100.0  False  0.506142854691
# 5   clothes   75.0  False  0.529857158661
# 9   clothes   50.0  False  0.512857139111
# 13  clothes   25.0  False  0.520285725594
# 17  clothes   10.0  False   0.54757142067
# 21  clothes    1.0  False  0.500999987125
#
# *************************************************
# Clothes augmentation
#           0      1     2               3
# 3   clothes  100.0  True   0.75985711813
# 7   clothes   75.0  True  0.780142843723
# 11  clothes   50.0  True  0.764857113361
# 15  clothes   25.0  True  0.738571405411
# 19  clothes   10.0  True   0.77685713768
# 23  clothes    1.0  True  0.763999998569
#
#
# ********************************
# ********************************
# All
#           0      1      2                  3
# 0     faces  100.0  False     0.999920606613
# 1   clothes  100.0  False     0.453673601151
# 2     faces  100.0   True     0.634844601154
# 3   clothes  100.0   True     0.236859470606
# 4     faces   75.0  False      13.9587841034
# 5   clothes   75.0  False    0.0173242203891
# 6     faces   75.0   True     0.801680028439
# 7   clothes   75.0   True      0.94264549017
# 8     faces   50.0  False  1.19999995718e-07
# 9   clothes   50.0  False      13.8504419327
# 10    faces   50.0   True      0.59063231945
# 11  clothes   50.0   True     0.346548855305
# 12    faces   25.0  False                1.0
# 13  clothes   25.0  False  5.59999989491e-07
# 14    faces   25.0   True     0.999365091324
# 15  clothes   25.0   True     0.327988296747
# 16    faces   10.0  False  1.27999999222e-06
# 17  clothes   10.0  False     0.620814025402
# 18    faces   10.0   True     0.994444429874
# 19  clothes   10.0   True     0.896589994431
# 20    faces    1.0  False     0.213675692677
# 21  clothes    1.0  False     0.420634925365
# 22    faces    1.0   True     0.333739906549
# 23  clothes    1.0   True     0.873015880585
#
# *************************************************
# Faces no augmentation
#         0      1      2                  3
# 0   faces  100.0  False     0.999920606613
# 4   faces   75.0  False      13.9587841034
# 8   faces   50.0  False  1.19999995718e-07
# 12  faces   25.0  False                1.0
# 16  faces   10.0  False  1.27999999222e-06
# 20  faces    1.0  False     0.213675692677
#
# *************************************************
# Faces augmentation
#         0      1     2               3
# 2   faces  100.0  True  0.634844601154
# 6   faces   75.0  True  0.801680028439
# 10  faces   50.0  True   0.59063231945
# 14  faces   25.0  True  0.999365091324
# 18  faces   10.0  True  0.994444429874
# 22  faces    1.0  True  0.333739906549
#
# *************************************************
# Clothes no augmentation
#           0      1      2                  3
# 1   clothes  100.0  False     0.453673601151
# 5   clothes   75.0  False    0.0173242203891
# 9   clothes   50.0  False      13.8504419327
# 13  clothes   25.0  False  5.59999989491e-07
# 17  clothes   10.0  False     0.620814025402
# 21  clothes    1.0  False     0.420634925365
#
# *************************************************
# Clothes augmentation
#           0      1     2               3
# 3   clothes  100.0  True  0.236859470606
# 7   clothes   75.0  True   0.94264549017
# 11  clothes   50.0  True  0.346548855305
# 15  clothes   25.0  True  0.327988296747
# 19  clothes   10.0  True  0.896589994431
# 23  clothes    1.0  True  0.873015880585
